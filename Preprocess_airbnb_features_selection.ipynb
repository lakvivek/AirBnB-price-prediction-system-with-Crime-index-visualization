# %%
import pandas as pd
import numpy as np
import csv

# %% [markdown]
# # Reading airbnb listing [Raw format]

# %%
raw_data = pd.read_csv('data/airbnb_raw.csv')
print "Total %s objects" % raw_data['id'].count()
# Out:
# Total 40753 objects
# /docs/anaconda/lib/python2.7/site-packages/IPython/core/interactiveshell.py:2717: DtypeWarning: Columns (43,88) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
raw_data.shape
# Out:
# (40753, 95)

# %% [markdown]
# # Selecting few features form raw data

# %%
header = [
#  'id',
 'host_neighbourhood',
 'host_identity_verified',
 'neighbourhood',
 'city',
 'zipcode',
 'property_type',
 'room_type',
 'accommodates',
 'bathrooms',
 'bedrooms',
 'beds',
 'bed_type',
 'square_feet',
 'security_deposit',
 'cleaning_fee',
 'guests_included',
 'extra_people',
 'availability_30',
 'availability_60',
 'availability_90',
 'availability_365',
 'number_of_reviews',
 'review_scores_rating',
 'review_scores_accuracy',
 'review_scores_cleanliness',
 'review_scores_checkin',
 'review_scores_communication',
 'review_scores_location',
 'review_scores_value',
 'cancellation_policy'
]

# %%
raw_data.to_csv('data/airbnb_features_selection.csv', columns = header, index=False)
data_features = pd.read_csv('data/airbnb_features_selection.csv')
print "Total %s objects" % data_features.count()
# Out:
# Total host_neighbourhood             35559
# host_identity_verified         40502
# neighbourhood                  34748
# city                           40709
# zipcode                        40142
# property_type                  40753
# room_type                      40753
# accommodates                   40753
# bathrooms                      40594
# bedrooms                       40684
# beds                           40674
# bed_type                       40753
# square_feet                      567
# security_deposit               17793
# cleaning_fee                   28061
# guests_included                40753
# extra_people                   40753
# availability_30                40753
# availability_60                40753
# availability_90                40753
# availability_365               40753
# number_of_reviews              40753
# review_scores_rating           30829
# review_scores_accuracy         30736
# review_scores_cleanliness      30768
# ...

# %%
pd.set_option('display.max_columns', None)
data_features
# Out:
#       host_neighbourhood host_identity_verified neighbourhood           city  \
# 0            City Island                      t   City Island          Bronx
# 1            City Island                      f   City Island          Bronx
# 2            City Island                      f   City Island          Bronx
# 3            City Island                      t   City Island    City Island
# 4            City Island                      t   City Island          Bronx
# 5                    NaN                      f           NaN          Bronx
# 6            City Island                      t   City Island    City Island
# 7               Allerton                      t      Allerton          Bronx
# 8             Baychester                      t    Baychester          Bronx
# 9             Baychester                      t    Baychester          Bronx
# 10            Baychester                      t    Baychester          Bronx
# ...

# %% [markdown]
# # Selecting Class label

# %%
header = ['price']
raw_data.to_csv('data/airbnb_class.csv', columns = header, index=False)
data_values = pd.read_csv('data/airbnb_class.csv')
print "Total %s objects" % data_values.count()
# Out:
# Total price    40753
# dtype: int64 objects

# %%
raw_data['host_neighbourhood'].unique()
# Out:
# array(['City Island', nan, 'Allerton', 'Baychester', 'Bronxdale',
#        'Ditmars / Steinway', 'Astoria', 'Greenwood Heights', 'Queens',
#        'Crown Heights', 'Silver Lake', 'Gerritsen Beach', 'Soundview',
#        'Ozone Park', 'Woodhaven', 'East New York', 'South Ozone Park',
#        'Richmond Hill', 'Tremont', 'Bedford Park', 'Fordham', 'Whitestone',
#        'Eltingville', 'South Beach', 'Grasmere', 'The Rockaways',
#        'Bushwick', 'Midtown East', 'Copacabana', 'Old West Austin',
#        'Columbia Street Waterfront', 'Comercio', 'Long Island City',
#        'East Harlem', 'Bath Beach', 'Bayside', 'Woodside',
#        'Upper East Side', 'Battery Park City', 'Financial District',
#        'Rittenhouse Square', 'Tribeca', 'Bay Ridge', 'Upper West Side',
#        'Sunset Park', 'Great Kills', 'Studio City', 'Bedford-Stuyvesant',
#        'Washington Heights', 'Clinton Hill', 'Stuyvesant Heights',
#        'Lefferts Garden', 'Williamsburg', 'Harlem', "Hell's Kitchen",
# ...
